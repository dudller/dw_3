# %% [markdown]
# <a href="https://colab.research.google.com/github/dudller/dw_3/blob/master/day_2_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix/part3/dw_3'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/part3/dw_3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ls
# Out:
# data/  README.md

# %%
train=pd.read_pickle('data/train.p')
train.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
X_train,y_train = train['features'],train['labels']

# %%
plt.imshow(X_train[0])

# %%
names=pd.read_csv('data/names.csv')

# %%
sign_names=names.to_dict()['b']

# %%
for id in sign_names.keys():
  given_signs=X_train[y_train==id]
  plt.figure(figsize=(15,5))
  for i in range(3):
    plt.subplot('19{0}'.format(i+1))
    plt.imshow(given_signs[i])
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from collections import  Counter

# %%
cnt=Counter(y_train).most_common()
id_labels,cnt_labels=zip(*cnt)
ids=range(len(id_labels))
plt.figure(figsize=(15,5))
plt.bar(ids,cnt_labels)
plt.xlabel("znaki")
labels=[sign_names[id_labels[id]] for id in id_labels]
plt.xticks(ids,labels,rotation='vertical')
plt.show()
